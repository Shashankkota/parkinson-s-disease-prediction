# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashankkota/parkinson-s-disease-prediction/blob/main/Parkinsons_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1)Make necessary imports:

# %% [markdown]
# Detecting Parkinson’s Disease with **XGBoost**

# %%
import numpy as np
import pandas as pd
import os, sys
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# 2)  Now lets import the parkinsons disease dataset from local storage(Source:UCI ML Parkinsons dataset) and then Read the data into a DataFrame and get the first 5 records

# %%
from google.colab import files
import pandas as pd

# Upload the file
uploaded = files.upload()

# Get the filename (assuming only one file is uploaded)
filename = list(uploaded.keys())[0]

# Read the file into a DataFrame
df = pd.read_csv(filename)

# Display the first few rows
df.head()
# Out:
#      <input type="file" id="files-7e22b811-bd96-4bca-b3dc-cf3db056be92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e22b811-bd96-4bca-b3dc-cf3db056be92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 3)Extract the features and labels from the dataset. The features include all columns except ‘status’, while the labels correspond to the values in the ‘status’ column.

# %%
#DataFlair - Get the features and labels
features=df.loc[:,df.columns!='status'].values[:,1:]
labels=df.loc[:,'status'].values

# %% [markdown]
# 4)The ‘status’ column contains labels 0 and 1. Let's determine the count of each label to understand their distribution.

# %%
print(labels[labels==1].shape[0], labels[labels==0].shape[0])
# Out:
# 147 48

# %% [markdown]
# Our dataset contains 147 instances labeled as 1 and 48 labeled as 0 in the ‘status’ column.
#
# 5)initialize a `MinMaxScaler` to normalize the features within a range of -1 to 1. This scaler adjusts the feature values proportionally within the specified range. The `fit_transform()` method is used to first compute the necessary scaling parameters and then apply the transformation. The labels remain unchanged as they do not require scaling.

# %%
scaler=MinMaxScaler((-1,1))
x=scaler.fit_transform(features)
y=labels

# %% [markdown]
# 6)Next, divide the dataset into training and testing sets, allocating 20% of the data for testing. This ensures the model is trained on the majority of the data while retaining a portion for evaluation.

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.2, random_state=7)

# %% [markdown]
# 7)Create an instance of XGBClassifier and train the model. This classifier utilizes eXtreme Gradient Boosting, a powerful gradient boosting algorithm designed for modern data science challenges. It belongs to the Ensemble Learning category in machine learning, where multiple models are trained and combined to generate a more accurate and robust prediction.

# %%
model=XGBClassifier()
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %% [markdown]
# Generate `y_pred`, which contains the predicted values for `x_test`, and evaluate the model’s accuracy. Finally, print the accuracy score to assess the model's performance.

# %%
y_pred=model.predict(x_test)
print(accuracy_score(y_test, y_pred)*100)
# Out:
# 94.87179487179486

# %% [markdown]
# In the given Parkinson’s Disease Detection Project, the model is trained on a dataset, but there is no direct user input to predict whether a patient has the disease.
#
# Now we need to add User Input for Prediction
# To allow user input (e.g., from a form or console), you need to:
#
# Collect the required features from the user.
# Preprocess the input like the training data.
# Use the trained XGBClassifier model to predict if the patient has Parkinson’s disease.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

df = pd.read_csv('parkinsons.data')

X = df.drop(columns=['name', 'status'])
y = df['status']

scaler = MinMaxScaler((-1, 1))
X_scaled = scaler.fit_transform(X)

x_train, x_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

model = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
model.fit(x_train, y_train)

def predict_parkinsons():
    print("Enter the following 22 values:")

    user_input = []
    feature_names = df.columns.drop(['name', 'status'])

    for feature in feature_names:
        value = float(input(f"{feature}: "))
        user_input.append(value)

    user_input = np.array(user_input).reshape(1, -1)
    user_input = scaler.transform(user_input)
    prediction = model.predict(user_input)

    if prediction[0] == 1:
        print("The model predicts that the patient has Parkinson’s Disease.")
    else:
        print("The model predicts that the patient does NOT have Parkinson’s Disease.")

predict_parkinsons()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-a72b560aa3cf> in <cell line: 0>()
#       7 from sklearn.metrics import accuracy_score
#       8
# ----> 9 df = pd.read_csv('parkinsons.data')
#      10
#      11 X = df.drop(columns=['name', 'status'])
#
# ...
